# %%
#dataframeobj[simple condition]
#dataframeobj[com pound condition]

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\prash\\OneDrive\\Desktop\\Pandas\\examdet.csv")
print(df)
df["total"]=df["telugu"]+df["english"]+df["hindi"]+df["maths"]+df["science"]+df["social"]
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
#simple condition
df.loc[df["maths"]>=90,["name"]]
# Out:
#        name
# 0    Ramesh
# 2    Rossum
# 4    Kalyan
# 6    Kambli
# 10    Biswa
# 12   Kalyan
# 13  shareef

# %%
#simple condition
df.loc[df["maths"]>=90,["htno","name"]]
# Out:
#     htno     name
# 0    100   Ramesh
# 2    102   Rossum
# 4    104   Kalyan
# 6    106   Kambli
# 10   110    Biswa
# 12   104   Kalyan
# 13   112  shareef

# %%
df.loc[((df["maths"]>=80) &(df["maths"]<=90),["htno","name"])]
# Out:
#     htno     name
# 7    107  Praveen
# 8    108   Ganesh
# 13   112  shareef
# 14   113     sonu

# %%
df.loc[((df["telugu"]>=50)&(df["hindi"]>60),["name"])]
# Out:
#        name
# 0    Ramesh
# 4    Kalyan
# 8    Ganesh
# 10    Biswa
# 11   Ritchi
# 12   Kalyan
# 13  shareef
# 14     sonu
# 16   Rakesh

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\prash\\OneDrive\\Desktop\\Pandas\\examdet.csv")
print(df)
df["total"]=df["telugu"]+df["english"]+df["hindi"]+df["maths"]+df["science"]+df["social"]
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
#now we are using the df.loc["compund condition"]
df.loc[((df["total"]>=350)&(df["total"]>400),["name"])]
# Out:
#        name
# 2    Rossum
# 6    Kambli
# 7   Praveen
# 11   Ritchi
# 13  shareef
# 14     sonu
# 16   Rakesh
